# %%
# Import packages
import numpy as np
import pprint
import ipdb
import pandas as pd
eps = np.finfo(float).eps
from numpy import log2 as log

# %%
# Load training data, split into train and validation sets
data = pd.read_csv("train.csv")
train_data = data.sample(frac=0.8)
val_data = data.drop(train_data.index)
discrete_attributes = ["Work_accident", "promotion_last_5years", "sales", "salary"]    
real_attributes = ["satisfaction_level", "last_evaluation", "number_project", "average_montly_hours", "time_spend_company"]

# %%
def entropy_before_split(train_data):
    """ Finds Entropy of dataset before any split """
    
    dependent_variable = "left"
    entropy = 0
    labels = train_data[dependent_variable].unique()
    for label in labels:
        temp = train_data[dependent_variable].value_counts()[label] / len(train_data[dependent_variable])
        entropy += -temp * log(temp + eps)
    return entropy

# %%
def entropy_on_real_attribute_split(train_data, attribute):
    """ Finds resulting entropy of dataset if it is split using attribute """
    
    dependent_variable = "left"
    class_labels = train_data[dependent_variable].unique()
    attribute_labels = train_data[attribute].unique()
    max_entropy = None
    split_point = None
    
    for attribute_label in attribute_labels:
        entropy = 0
        entropy_after_split = 0
        
        for class_label in class_labels:
            numer = len(train_data[attribute][train_data[attribute] <= attribute_label][train_data[dependent_variable] == class_label])
            denom = len(train_data[attribute][train_data[attribute] <= attribute_label])
            temp = numer / (denom + eps)
            entropy += -temp * log(temp + eps)
        temp2 = denom / len(train_data)
        entropy_after_split += -temp2 * entropy
        
        entropy = 0    
        for class_label in class_labels:
            numer = len(train_data[attribute][train_data[attribute] > attribute_label][train_data[dependent_variable] == class_label])
            denom = len(train_data[attribute][train_data[attribute] > attribute_label])
            temp = numer / (denom + eps)
            entropy += -temp * log(temp + eps)
        temp2 = denom / len(train_data)
        entropy_after_split += -temp2 * entropy
            
        if (max_entropy == None or (max_entropy > abs(entropy_after_split))):
            max_entropy = abs(entropy_after_split)
            split_point = attribute_label
        
    return max_entropy, split_point

# %%
def entropy_on_discrete_attribute_split(train_data, attribute):
    """ Finds resulting entropy of dataset if it is split using attribute """
    entropy_after_split = 0
    dependent_variable = "left"
    class_labels = train_data[dependent_variable].unique()
    attribute_labels = train_data[attribute].unique()

    for attribute_label in attribute_labels:
        entropy = 0
        for class_label in class_labels:
            numer = len(train_data[attribute][train_data[attribute] == attribute_label][train_data[dependent_variable] == class_label])
            denom = len(train_data[attribute][train_data[attribute] == attribute_label])
            temp = numer / (denom + eps)
            entropy += -temp * log(temp + eps)
        temp2 = denom / len(train_data)
        entropy_after_split += -temp2 * entropy
    return abs(entropy_after_split)

# %%
def split_criteria(train_data):
    """ Finds the best attribute to split on """
    
    Info_gain_discrete = {}
    initialEntropy = entropy_before_split(train_data)
    Info_gain = None
    split_point = None
    max_gain_attribute = None
    
    for key in discrete_attributes:
        Info_gain_discrete[key] = initialEntropy - entropy_on_discrete_attribute_split(train_data, key)
        
    for key in real_attributes:
        max_entropy, max_entropy_val = entropy_on_real_attribute_split(train_data, key)
        if (Info_gain == None or initialEntropy - max_entropy > Info_gain):
            Info_gain = initialEntropy - max_entropy
            split_point = max_entropy_val
            max_gain_attribute = key
             
    first = max(Info_gain_discrete, key=lambda k: Info_gain_discrete[k])
    if Info_gain_discrete[first] > Info_gain:
        Info_gain = Info_gain_discrete[first]
        max_gain_attribute = first
    return Info_gain, max_gain_attribute, split_point
    return Info_gain_discrete[first], first

# %%
def split_dataset_smaller(train_data, feature, split_point):
    return train_data[train_data[feature] <= split_point].reset_index(drop = True)

# %%
def split_dataset_greater(train_data, feature, split_point):
      return train_data[train_data[feature] > split_point].reset_index(drop = True)

# %%
def split_dataset(train_data, feature, label):
    """ This splits the dataset on given feature and all of its values """
    return train_data[train_data[feature] == label].reset_index(drop = True)

# %%
def most_probable(train_data):
    dependent_variable = "left"
    count_left = len(train_data[train_data[dependent_variable] == 0])
    count_right = len(train_data[train_data[dependent_variable] == 1])
    if count_left > count_right:
        return 0
    else:
        return 1

# %%
def Decision_tree(train_data):
    """ Builds tree recursively """
    
    D_tree = {}
    dependent_variable = "left"
    Info_gain, root, split_point = split_criteria(train_data)
    if Info_gain == 0.0:
        return most_probable(train_data)
    
    D_tree[root] = {}
    
    if root in (discrete_attributes):
        labels = train_data[root].unique()
        for label in labels:
            split_data = split_dataset(train_data, root, label)
            unique_labels = split_data[dependent_variable].unique()
            if len(unique_labels) == 1:
                D_tree[root][label] = unique_labels[0]
            else:
                D_tree[root][label] = Decision_tree(split_data)
        return D_tree

    else:
        split_data = split_dataset_smaller(train_data, root, split_point)
        unique_labels = split_data[dependent_variable].unique()
        if len(unique_labels) == 1:
            D_tree[root][split_point] = unique_labels[0]
        else:
            D_tree[root][split_point] = Decision_tree(split_data)
            
        split_data = split_dataset_greater(train_data, root, split_point)
        unique_labels = split_data[dependent_variable].unique()
        if len(unique_labels) == 1:
            D_tree[root][split_point + 0.000000001] = unique_labels[0]
        else:
            D_tree[root][split_point + 0.000000001] = Decision_tree(split_data)
    
        return D_tree

# %%
def predict(inst, tree):
    for nodes in tree.keys():        
        value = inst[nodes]
        if nodes in discrete_attributes:
            if value in list((tree[nodes]).keys()):
                tree = tree[nodes][value]
            else:
                zeros = 0
                ones = 0
                for i in tree[nodes].keys():
                    if tree[nodes][i] == 0:
                        zeros += 1
                    elif tree[nodes][i] == 1:
                        ones += 1
                if zeros > ones:
                    return 0
                else:
                    return 1

        elif nodes in real_attributes:
            first_key = list(tree[nodes].keys())[0]
            if value <= first_key :
                tree = tree[nodes][first_key]
            else:
                second_key = list(tree[nodes].keys())[1]
                tree = tree[nodes][second_key]
        prediction = 0

        if type(tree) is dict:
            prediction = predict(inst, tree)
        else:
            prediction = tree
            break;

    return prediction

# %%
# def predict(inst, tree):
#     #This function is used to predict for any input variable  
#     #Recursively we go through the tree that we built earlier
#     for nodes in tree.keys():        
#         value = inst[nodes]
#         if nodes in discrete_attributes:
#             if value not in tree.keys():
#                 count_left = 0
#                 count_right = 1
#                 for i in tree[nodes].values():
#                     if (type(i) != dict):
#                         if(i == 1):
#                             count_right += 1
#                         else:
#                             count_left += 0
#                 return max(count_left, count_right)
#             else:
#                 tree = tree[nodes][value]
#         else:
#             if (value <= list((tree[nodes]).keys())[0]):
#                 tree = tree[nodes][list((tree[nodes]).keys())[0]]
#             else:
#                 tree = tree[nodes][list((tree[nodes]).keys())[1]]
#         prediction = 0
#         if type(tree) is dict:
#             prediction = predict(inst, tree)
#         else:
#             prediction = tree
#             break;                            
        
#     return prediction

# %%
def validate_tree(val_data, tree):
    predicted = []
    for index, row in val_data.iterrows():
        predicted.append(predict(row, tree))
    actual = val_data["left"].tolist()
    true_pos = 0
    true_neg = 0
    false_pos = 0
    false_neg = 0
    
    for i in range(0, len(predicted)):
        if (predicted[i] == 0 and actual[i] == 0):
            true_neg += 1
        elif (predicted[i] == 0 and actual[i] == 1):
            false_neg += 1
        elif (predicted[i] == 1 and actual[i] == 0):
            false_pos += 1
        else:
            true_pos += 1
    return true_pos, true_neg, false_pos, false_neg

# %%
def accuracy(val_data, tree):
    true_pos, true_neg, false_pos, false_neg = validate_tree(val_data, tree)
    print (true_pos, true_neg, false_pos, false_neg)
    total_instances = true_neg + true_pos + false_neg + false_pos
    accuracy_estimate = (true_neg + true_pos) / (total_instances)
    precision_estimate = true_pos / (true_pos + false_pos)
    recall_estimate = (true_pos) / (true_pos + false_neg)
    f1_score = (1 / recall_estimate) + (1 / precision_estimate)
    f1_score = 2 / f1_score
    print ("Accuracy : ", accuracy_estimate)
    print ("Precision : ", precision_estimate)
    print ("Recall : ", recall_estimate)
    print ("F1_Score : ", f1_score)

# %%
tree = Decision_tree(train_data)
accuracy(val_data, tree)
# Out:
# 492 1154 579 23
# Accuracy :  0.7322064056939501
# Precision :  0.45938375350140054
# Recall :  0.9553398058252427
# F1_Score :  0.6204287515762925

# %%
tree
# Out:
# {'satisfaction_level': {0.46: {'satisfaction_level': {0.11: 1,
#     0.110000001: {'number_project': {2: {'average_montly_hours': {161: {'last_evaluation': {0.57: {'last_evaluation': {0.44: 0,
#             0.44000000100000003: {'satisfaction_level': {0.31: 0,
#               0.310000001: {'average_montly_hours': {125: 0,
#                 125.000000001: {'salary': {'high': {'sales': {'IT': 0,
#                     'RandD': 1,
#                     'accounting': 1,
#                     'marketing': 1,
#                     'product_mng': 1,
#                     'sales': 1,
#                     'support': {'satisfaction_level': {0.36: 0,
#                       0.360000001: 1}},
#                     'technical': 1}},
#                   'low': {'sales': {'IT': 1,
#                     'RandD': 1,
#                     'accounting': 1,
#                     'hr': 1,
#                     'management': 1,
#                     'marketing': 1,
#                     'product_mng': 1,
#                     'sales': {'average_montly_hours': {150: 1,
#                       150.000000001: {'average_montly_hours': {151: {'satisfaction_level': {0.39: 1,
#                           0.39000000100000004: 0}},
#                         151.000000001: 1}}}},
#                     'support': {'average_montly_hours': {132: {'last_evaluation': {0.54: 1,
#                         0.540000001: 0}},
#                       132.000000001: 1}},
#                     'technical': 1}},
#                   'medium': 1}}}}}}}},
#           0.5700000009999999: {'sales': {'IT': 0,
#             'RandD': 0,
#             'accounting': 0,
#             'management': 0,
#             'product_mng': 0,
#             'sales': 0,
#             'support': 0,
#             'technical': {'average_montly_hours': {136: 0,
#               136.000000001: 1}}}}}},
#         161.000000001: {'sales': {'IT': 0,
#           'RandD': 0,
#           'accounting': 0,
#           'hr': 0,
#           'management': 0,
#           'marketing': {'satisfaction_level': {0.21: 0, 0.210000001: 1}},
#           'product_mng': 0,
#           'sales': {'satisfaction_level': {0.41: 0,
#             0.410000001: {'salary': {'low': 0,
#               'medium': {'last_evaluation': {0.46: 0,
#                 0.46000000100000005: 1}}}}}},
#           'support': 0,
#           'technical': 0}}}},
#       2.000000001: {'number_project': {6: {'average_montly_hours': {287: {'satisfaction_level': {0.29: {'sales': {'IT': {'satisfaction_level': {0.14: {'last_evaluation': {0.55: {'satisfaction_level': {0.12: 0,
#                     0.120000001: 1}},
#                   0.550000001: 0}},
#                 0.140000001: 0}},
#               'RandD': {'last_evaluation': {0.99: {'last_evaluation': {0.5: {'time_spend_company': {5: {'time_spend_company': {2: 1,
#                       2.000000001: 0}},
#                     5.000000001: 1}},
#                   0.500000001: 0}},
#                 0.990000001: 1}},
#               'accounting': {'last_evaluation': {0.65: {'average_montly_hours': {217: 0,
#                   217.000000001: {'last_evaluation': {0.45: 1,
#                     0.45000000100000004: {'satisfaction_level': {0.16: 1,
#                       0.160000001: 0}}}}}},
#                 0.650000001: 0}},
#               'hr': 0,
#               'management': 0,
#               'marketing': 0,
#               'product_mng': 0,
#               'sales': {'average_montly_hours': {231: 0,
#                 231.000000001: {'satisfaction_level': {0.2: {'time_spend_company': {5: {'satisfaction_level': {0.13: 0,
#                       0.130000001: {'last_evaluation': {0.84: {'last_evaluation': {0.8: {'number_project': {5: {'last_evaluation': {0.73: 0,
#                               0.730000001: {'satisfaction_level': {0.14: 1,
#                                 0.140000001: 0}}}},
#                             5.000000001: 1}},
#                           0.800000001: 1}},
#                         0.8400000009999999: 0}}}},
#                     5.000000001: 0}},
#                   0.200000001: 0}}}},
#               'support': {'average_montly_hours': {152: {'satisfaction_level': {0.15: {'salary': {'high': 1,
#                     'low': 1,
#                     'medium': 0}},
#                   0.150000001: 0}},
#                 152.000000001: 0}},
#               'technical': {'satisfaction_level': {0.14: {'Work_accident': {0: 0,
#                   1: {'satisfaction_level': {0.13: 0, 0.130000001: 1}}}},
#                 0.140000001: 0}}}},
#             0.290000001: {'last_evaluation': {0.52: 0,
#               0.520000001: {'average_montly_hours': {131: 0,
#                 131.000000001: {'sales': {'IT': 0,
#                   'RandD': {'last_evaluation': {0.87: 0,
#                     0.870000001: {'number_project': {3: 0, 3.000000001: 1}}}},
#                   'accounting': {'last_evaluation': {0.56: {'satisfaction_level': {0.31: 1,
#                       0.310000001: 0}},
#                     0.560000001: 0}},
#                   'hr': 0,
#                   'management': {'average_montly_hours': {204: 0,
#                     204.000000001: {'satisfaction_level': {0.36: 0,
#                       0.360000001: 1}}}},
#                   'marketing': 0,
#                   'product_mng': {'number_project': {5: 0,
#                     5.000000001: {'satisfaction_level': {0.31: 1,
#                       0.310000001: {'satisfaction_level': {0.32: 0,
#                         0.32000000100000003: 1}}}}}},
#                   'sales': {'satisfaction_level': {0.35: {'last_evaluation': {0.86: {'number_project': {3: 0,
#                         3.000000001: {'satisfaction_level': {0.31: 1,
#                           0.310000001: {'time_spend_company': {2: 1,
#                             2.000000001: 0}}}}}},
#                       0.860000001: 1}},
#                     0.350000001: {'average_montly_hours': {199: 0,
#                       199.000000001: {'satisfaction_level': {0.41: 0,
#                         0.410000001: {'number_project': {3: 1,
#                           3.000000001: {'average_montly_hours': {212: {'last_evaluation': {0.55: 0,
#                               0.550000001: 1}},
#                             212.000000001: 0}}}}}}}}}},
#                   'support': {'number_project': {4: 0,
#                     4.000000001: {'average_montly_hours': {219: 1,
#                       219.000000001: 0}}}},
#                   'technical': {'satisfaction_level': {0.42: {'satisfaction_level': {0.41: {'average_montly_hours': {139: {'satisfaction_level': {0.37: 0,
#                           0.370000001: 1}},
#                         139.000000001: {'number_project': {4: {'average_montly_hours': {179: 0,
#                             179.000000001: {'last_evaluation': {0.6: 0,
#                               0.600000001: 1}}}},
#                           4.000000001: 0}}}},
#                       0.410000001: {'average_montly_hours': {181: 0,
#                         181.000000001: 1}}}},
#                     0.420000001: 0}}}}}}}}}},
#           287.000000001: 1}},
#         6.000000001: 1}}}}}},
#   0.46000000100000005: {'time_spend_company': {4: {'average_montly_hours': {287: {'number_project': {5: {'number_project': {2: {'sales': {'IT': {'last_evaluation': {0.98: 0,
#               0.980000001: 1}},
#             'RandD': {'last_evaluation': {0.75: 0,
#               0.750000001: {'satisfaction_level': {0.53: 0,
#                 0.530000001: {'average_montly_hours': {133: 0,
#                   133.000000001: 1}}}}}},
#             'accounting': 0,
#             'hr': 0,
#             'management': 0,
#             'marketing': 0,
#             'product_mng': 0,
#             'sales': {'average_montly_hours': {252: {'last_evaluation': {0.89: 0,
#                 0.890000001: {'last_evaluation': {0.9: 1, 0.900000001: 0}}}},
#               252.000000001: {'last_evaluation': {0.53: {'satisfaction_level': {0.56: 0,
#                   0.560000001: 1}},
#                 0.530000001: 0}}}},
#             'support': {'last_evaluation': {0.77: 0,
#               0.770000001: {'last_evaluation': {0.86: {'satisfaction_level': {0.74: {'satisfaction_level': {0.65: 1,
#                     0.650000001: 0}},
#                   0.740000001: 1}},
#                 0.860000001: 0}}}},
#             'technical': {'satisfaction_level': {0.48: 1,
#               0.480000001: {'average_montly_hours': {252: 0,
#                 252.000000001: {'salary': {'low': 1, 'medium': 0}}}}}}}},
#           2.000000001: {'time_spend_company': {3: {'sales': {'IT': 0,
#               'RandD': {'satisfaction_level': {0.47: 1, 0.470000001: 0}},
#               'accounting': {'satisfaction_level': {0.5: {'average_montly_hours': {138: {'last_evaluation': {0.61: 0,
#                     0.610000001: 1}},
#                   138.000000001: 0}},
#                 0.500000001: 0}},
#               'hr': {'satisfaction_level': {0.63: {'satisfaction_level': {0.57: 0,
#                   0.5700000009999999: {'satisfaction_level': {0.58: {'average_montly_hours': {196: 0,
#                       196.000000001: 1}},
#                     0.5800000009999999: {'last_evaluation': {0.89: 0,
#                       0.890000001: {'last_evaluation': {0.93: 1,
#                         0.930000001: 0}}}}}}}},
#                 0.630000001: 0}},
#               'management': {'promotion_last_5years': {0: 0,
#                 1: {'salary': {'high': 0, 'low': 1, 'medium': 0}}}},
#               'marketing': 0,
#               'product_mng': 0,
#               'sales': {'satisfaction_level': {0.8: {'satisfaction_level': {0.77: {'number_project': {3: 0,
#                     3.000000001: {'average_montly_hours': {236: {'average_montly_hours': {235: {'average_montly_hours': {163: 0,
#                           163.000000001: {'average_montly_hours': {164: {'satisfaction_level': {0.54: 1,
#                               0.540000001: 0}},
#                             164.000000001: {'last_evaluation': {0.99: {'average_montly_hours': {215: 0,
#                                 215.000000001: {'average_montly_hours': {219: {'last_evaluation': {0.8: {'last_evaluation': {0.54: {'last_evaluation': {0.53: 0,
#                                         0.530000001: 1}},
#                                       0.540000001: 0}},
#                                     0.800000001: 1}},
#                                   219.000000001: 0}}}},
#                               0.990000001: {'satisfaction_level': {0.71: 0,
#                                 0.7100000009999999: 1}}}}}}}},
#                         235.000000001: {'satisfaction_level': {0.56: 1,
#                           0.560000001: 0}}}},
#                       236.000000001: 0}}}},
#                   0.770000001: {'last_evaluation': {0.45: 1,
#                     0.45000000100000004: {'number_project': {3: {'last_evaluation': {0.63: 0,
#                         0.630000001: {'last_evaluation': {0.81: {'salary': {'high': 0,
#                             'low': 1,
#                             'medium': 1}},
#                           0.810000001: 0}}}},
#                       3.000000001: 0}}}}}},
#                 0.800000001: 0}},
#               'support': {'satisfaction_level': {0.49: {'last_evaluation': {0.61: 0,
#                   0.610000001: {'last_evaluation': {0.73: 1,
#                     0.730000001: 0}}}},
#                 0.490000001: {'number_project': {3: {'time_spend_company': {2: {'salary': {'high': 0,
#                       'low': 0,
#                       'medium': {'satisfaction_level': {0.85: {'satisfaction_level': {0.83: {'last_evaluation': {0.92: 0,
#                             0.920000001: {'last_evaluation': {0.94: 1,
#                               0.9400000009999999: 0}}}},
#                           0.8300000009999999: {'last_evaluation': {0.58: 1,
#                             0.5800000009999999: 0}}}},
#                         0.850000001: 0}}}},
#                     2.000000001: 0}},
#                   3.000000001: 0}}}},
#               'technical': {'average_montly_hours': {134: {'satisfaction_level': {0.51: {'satisfaction_level': {0.48: 0,
#                     0.480000001: 1}},
#                   0.510000001: 0}},
#                 134.000000001: {'average_montly_hours': {262: 0,
#                   262.000000001: {'average_montly_hours': {263: {'satisfaction_level': {0.71: 0,
#                       0.7100000009999999: {'satisfaction_level': {0.86: 1,
#                         0.860000001: 0}}}},
#                     263.000000001: 0}}}}}}}},
#             3.000000001: {'sales': {'IT': 0,
#               'RandD': 0,
#               'accounting': 0,
#               'hr': {'last_evaluation': {0.83: 0,
#                 0.8300000009999999: {'last_evaluation': {0.88: {'satisfaction_level': {0.76: 1,
#                     0.760000001: 0}},
#                   0.880000001: 0}}}},
#               'management': 0,
#               'marketing': {'number_project': {4: 0,
#                 4.000000001: {'salary': {'high': 0,
#                   'low': {'satisfaction_level': {0.62: 1, 0.620000001: 0}},
#                   'medium': 0}}}},
#               'product_mng': 0,
#               'sales': {'satisfaction_level': {0.47: 1,
#                 0.470000001: {'salary': {'high': 0,
#                   'low': {'average_montly_hours': {220: {'average_montly_hours': {218: {'last_evaluation': {0.86: 0,
#                         0.860000001: {'last_evaluation': {0.92: {'average_montly_hours': {154: {'satisfaction_level': {0.62: 1,
#                               0.620000001: {'last_evaluation': {0.91: 0,
#                                 0.910000001: 1}}}},
#                             154.000000001: 0}},
#                           0.920000001: 0}}}},
#                       218.000000001: 1}},
#                     220.000000001: 0}},
#                   'medium': 0}}}},
#               'support': {'satisfaction_level': {0.5: {'number_project': {4: 0,
#                   4.000000001: 1}},
#                 0.500000001: {'Work_accident': {0: 0,
#                   1: {'last_evaluation': {0.79: 0,
#                     0.790000001: {'last_evaluation': {0.81: 1,
#                       0.810000001: 0}}}}}}}},
#               'technical': {'last_evaluation': {0.59: 0,
#                 0.5900000009999999: {'last_evaluation': {0.6: {'satisfaction_level': {0.55: 1,
#                     0.550000001: 0}},
#                   0.600000001: {'salary': {'high': 0,
#                     'low': {'satisfaction_level': {0.72: 0,
#                       0.720000001: {'satisfaction_level': {0.73: 1,
#                         0.730000001: {'last_evaluation': {0.74: {'last_evaluation': {0.64: 0,
#                             0.640000001: {'satisfaction_level': {0.84: 1,
#                               0.8400000009999999: {'last_evaluation': {0.7: {'number_project': {3: 0,
#                                   3.000000001: 1}},
#                                 0.7000000009999999: 0}}}}}},
#                           0.740000001: 0}}}}}},
#                     'medium': {'satisfaction_level': {0.51: {'last_evaluation': {0.83: 1,
#                         0.8300000009999999: 0}},
#                       0.510000001: 0}}}}}}}}}}}}}},
#         5.000000001: {'sales': {'IT': {'average_montly_hours': {161: {'salary': {'high': 0,
#               'low': 1,
#               'medium': 1}},
#             161.000000001: 0}},
#           'RandD': 0,
#           'accounting': 0,
#           'hr': 0,
#           'management': {'satisfaction_level': {0.85: {'satisfaction_level': {0.83: {'satisfaction_level': {0.66: 1,
#                 0.660000001: 0}},
#               0.8300000009999999: 1}},
#             0.850000001: 0}},
#           'marketing': {'satisfaction_level': {0.53: 1, 0.530000001: 0}},
#           'product_mng': 0,
#           'sales': {'last_evaluation': {0.89: 0,
#             0.890000001: {'time_spend_company': {2: {'satisfaction_level': {0.73: 1,
#                 0.730000001: 0}},
#               2.000000001: 0}}}},
#           'support': {'last_evaluation': {0.98: {'salary': {'high': 0,
#               'low': 0,
#               'medium': {'satisfaction_level': {0.74: 0, 0.740000001: 1}}}},
#             0.980000001: 1}},
#           'technical': {'satisfaction_level': {0.7: {'salary': {'low': {'last_evaluation': {0.84: 1,
#                 0.8400000009999999: 0}},
#               'medium': {'number_project': {6: 0, 6.000000001: 1}}}},
#             0.7000000009999999: 0}}}}}},
#       287.000000001: 1}},
#     4.000000001: {'last_evaluation': {0.8: {'sales': {'IT': {'average_montly_hours': {166: {'last_evaluation': {0.73: {'average_montly_hours': {163: 0,
#               163.000000001: 1}},
#             0.730000001: 1}},
#           166.000000001: 0}},
#         'RandD': {'number_project': {4: 0,
#           4.000000001: {'satisfaction_level': {0.64: 0,
#             0.640000001: {'satisfaction_level': {0.68: 1, 0.680000001: 0}}}}}},
#         'accounting': 0,
#         'hr': {'average_montly_hours': {275: 0,
#           275.000000001: {'satisfaction_level': {0.53: 1, 0.530000001: 0}}}},
#         'management': 0,
#         'marketing': {'last_evaluation': {0.69: 0,
#           0.6900000009999999: {'satisfaction_level': {0.56: 0,
#             0.560000001: 1}}}},
#         'product_mng': 0,
#         'sales': 0,
#         'support': {'last_evaluation': {0.62: 0,
#           0.620000001: {'last_evaluation': {0.7: {'satisfaction_level': {0.89: {'average_montly_hours': {156: 0,
#                 156.000000001: 1}},
#               0.890000001: 0}},
#             0.7000000009999999: 0}}}},
#         'technical': {'salary': {'high': {'satisfaction_level': {0.8: 1,
#             0.800000001: 0}},
#           'low': {'average_montly_hours': {153: {'average_montly_hours': {134: 0,
#               134.000000001: 1}},
#             153.000000001: 0}},
#           'medium': {'satisfaction_level': {0.57: {'satisfaction_level': {0.53: {'number_project': {6: 0,
#                 6.000000001: 1}},
#               0.530000001: 1}},
#             0.5700000009999999: 0}}}}}},
#       0.800000001: {'average_montly_hours': {216: {'salary': {'high': 0,
#           'low': {'time_spend_company': {5: {'number_project': {3: {'sales': {'IT': 0,
#                 'hr': 1,
#                 'product_mng': 1,
#                 'sales': 1,
#                 'support': 1,
#                 'technical': 0}},
#               3.000000001: 0}},
#             5.000000001: {'last_evaluation': {0.99: {'last_evaluation': {0.83: {'satisfaction_level': {0.54: 1,
#                   0.540000001: 0}},
#                 0.8300000009999999: 0}},
#               0.990000001: 1}}}},
#           'medium': 0}},
#         216.000000001: {'satisfaction_level': {0.71: {'sales': {'IT': 0,
#             'RandD': 0,
#             'accounting': {'satisfaction_level': {0.55: 0,
#               0.550000001: {'satisfaction_level': {0.63: 1, 0.630000001: 0}}}},
#             'management': 0,
#             'marketing': 0,
#             'product_mng': 0,
#             'sales': {'last_evaluation': {0.91: 0,
#               0.910000001: {'satisfaction_level': {0.66: 1, 0.660000001: 0}}}},
#             'support': 0,
#             'technical': {'satisfaction_level': {0.48: 1, 0.480000001: 0}}}},
#           0.7100000009999999: {'number_project': {3: {'average_montly_hours': {286: 0,
#               286.000000001: 1}},
#             3.000000001: {'time_spend_company': {6: {'satisfaction_level': {0.92: {'number_project': {5: {'average_montly_hours': {276: {'sales': {'IT': 1,
#                       'RandD': 1,
#                       'accounting': 1,
#                       'hr': 1,
#                       'management': {'satisfaction_level': {0.85: 1,
#                         0.850000001: 0}},
#                       'marketing': 1,
#                       'product_mng': 1,
#                       'sales': {'average_montly_hours': {235: {'average_montly_hours': {234: {'last_evaluation': {0.87: {'number_project': {4: 0,
#                               4.000000001: 1}},
#                             0.870000001: 1}},
#                           234.000000001: 0}},
#                         235.000000001: 1}},
#                       'support': {'average_montly_hours': {271: 1,
#                         271.000000001: {'last_evaluation': {0.87: {'satisfaction_level': {0.8: 1,
#                             0.800000001: 0}},
#                           0.870000001: 1}}}},
#                       'technical': {'satisfaction_level': {0.85: 1,
#                         0.850000001: {'satisfaction_level': {0.86: {'average_montly_hours': {238: 0,
#                             238.000000001: 1}},
#                           0.860000001: 1}}}}}},
#                     276.000000001: 0}},
#                   5.000000001: 0}},
#                 0.920000001: 0}},
#               6.000000001: 0}}}}}}}}}}}}}}
